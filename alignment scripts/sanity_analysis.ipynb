# %%
import pandas as pd

# %%
sane = pd.read_csv('sanity.tsv', sep='\t', header=0)

# %%
metrics = list(sane.columns)[0:-9]
# list(sane.columns)
# sane[['okay/perf/bad', 'align issue']]

# %%
for m in metrics:
    print(sane[[m, 'okay/perf/bad', 'align issue']].sort_values(by=[m]))
# Out:
#     glove_src_para_sim okay/perf/bad align issue
# 7             0.635219             p           n
# 19            0.649812             b           y
# 14            0.708574             p           n
# 4             0.783972             o           y
# 9             0.785037             o           y
# 5             0.799433             o           y
# 8             0.801659             o           y
# 2             0.802374             p           n
# 12            0.829401             b           n
# 0             0.846651             o           n
# 16            0.848475             b           n
# 6             0.851340             p           n
# 17            0.852264             b           n
# 3             0.859768             p           n
# 15            0.884324             p           n
# 13            0.888366             b           n
# 18            0.889149             b           y
# 10            0.898563             b           n
# ...
